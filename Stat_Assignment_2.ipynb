# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('/content/sample_data/california_housing_test.csv')
d.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
print(d)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
X=[37.37,34.26,33.78,33.82,36.33]
X_mean=np.mean(d['latitude'])
print(X_mean)
X_var=np.var(d['latitude'])
print(X_var)
# Out:
# 35.635389999999994
# 4.5339804479

# %%
import numpy as np
y=[27.0,43.0,27.0,28.0,19.0]
y_mean=np.mean(d['housing_median_age'])
print(y_mean)
y_mean=np.var(d['housing_median_age'])
print(y_var)
# Out:
# 28.845333333333333
# 172710.9642328889

# %%
import numpy as np
y=[3885.0,1510.0,3589.0,67.0,1241.0]
y_mean=np.mean(d['total_rooms'])
print(y_mean)
y_var=np.var(d['total_rooms'])
print(y_var)
# Out:
# 2599.578666666667
# 4645033.750478223

# %%
import numpy as np
y=[661.0,310.0,507.0,15.0,244.0]
y_mean=np.mean(d['total_bedrooms'])
print(y_mean)
y_var=np.var(d['total_bedrooms'])
print(y_var)
# Out:
# 529.9506666666666
# 172710.9642328889

# %% [markdown]
# Maximum Likelihood Estimation

# %%
x=50
print("Maximum Likelihood Estimation of latitude:")
print("")
d['result']=(1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[['latitude','result']])
# Out:
# Maximum Likelihood Estimation of latitude:
#
#       latitude    result
# 0        37.37 -0.001189
# 1        34.26 -0.001189
# 2        33.78 -0.001189
# 3        33.82 -0.001189
# 4        36.33 -0.001189
# ...        ...       ...
# 2995     34.42 -0.001189
# 2996     34.06 -0.001189
# 2997     36.30 -0.001189
# 2998     34.10 -0.001189
# 2999     34.42 -0.001189
#
# [3000 rows x 2 columns]

# %%
x=75
print("Maximum Likelihood Estimation of latitude:")
print("")
d['result']=(1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[['latitude','result']])
# Out:
# Maximum Likelihood Estimation of latitude:
#
#       latitude    result
# 0        37.37  0.008202
# 1        34.26  0.008202
# 2        33.78  0.008202
# 3        33.82  0.008202
# 4        36.33  0.008202
# ...        ...       ...
# 2995     34.42  0.008202
# 2996     34.06  0.008202
# 2997     36.30  0.008202
# 2998     34.10  0.008202
# 2999     34.42  0.008202
#
# [3000 rows x 2 columns]

# %%
x=80
print("Maximum Likelihood Estimation of latitude:")
print("")
d['result']=(1/np.sqrt(2*np.pi*np.mean(d['latitude']**2))*np.log(((x-np.std(d['latitude']))**2)/(2*np.mean(d['latitude']**2))))
print(d[['latitude','result']])
# Out:
# Maximum Likelihood Estimation of latitude:
#
#       latitude    result
# 0        37.37  0.009686
# 1        34.26  0.009686
# 2        33.78  0.009686
# 3        33.82  0.009686
# 4        36.33  0.009686
# ...        ...       ...
# 2995     34.42  0.009686
# 2996     34.06  0.009686
# 2997     36.30  0.009686
# 2998     34.10  0.009686
# 2999     34.42  0.009686
#
# [3000 rows x 2 columns]

# %% [markdown]
# Question-2

# %%
mu=np.mean(d['latitude'])
sigma=np.var(d['latitude'],ddof=1)

# %%
def log_likelihood(x,mu,sigma):

  return -0.5*(np.log(2*np.pi*sigma**2)+((x-mu)**2/sigma**2))

# %%
values=[50,75,80]
log_likelihoods=[log_likelihood(v,mu,sigma)for v in values]

# %%
print("Mean :",mu)
print("Variance:",sigma)
print("Log-Likelihoods for values [50,75,80]:",log_likelihoods)
# Out:
# Mean : 35.635389999999994
# Variance: 4.535492278659553
# Log-Likelihoods for values [50,75,80]: [-7.44630962038779, -40.09544502376272, -50.271236300833074]

# %% [markdown]
# Question-3

# %%
import matplotlib.pyplot as plt
columns=['latitude','total_rooms','housing_median_age','total_bedrooms']
bins=5
for column in columns:
         plt.figure(figsize=(10,6))
         plt.hist(d[column],bins=bins,density=True,alpha=0.6,color='blue',edgecolor='black')
         plt.title(f'Density plot for {column}')
         plt.xlabel(column)
         plt.ylabel('Density')
         plt.grid(True)
         plt.show()

# %%
columns=['latitude','total_rooms','housing_median_age','total_bedrooms']
bins=10
for column in columns:
         plt.figure(figsize=(10,6))
         plt.hist(d[column],bins=bins,density=True,alpha=0.6,color='blue',edgecolor='black')
         plt.title(f'Density plot for {column}')
         plt.xlabel(column)
         plt.ylabel('Density')
         plt.grid(True)
         plt.show()

# %%
columns=['latitude','total_rooms','housing_median_age','total_bedrooms']
bins=15
for column in columns:
         plt.figure(figsize=(10,6))
         plt.hist(d[column],bins=bins,density=True,alpha=0.6,color='blue',edgecolor='black')
         plt.title(f'Density plot for {column}')
         plt.xlabel(column)
         plt.ylabel('Density')
         plt.grid(True)
         plt.show()

# %%
columns=['latitude','total_rooms','housing_median_age','total_bedrooms']
bins=20
for column in columns:
         plt.figure(figsize=(10,6))
         plt.hist(d[column],bins=bins,density=True,alpha=0.6,color='blue',edgecolor='black')
         plt.title(f'Density plot for {column}')
         plt.xlabel(column)
         plt.ylabel('Density')
         plt.grid(True)
         plt.show()
